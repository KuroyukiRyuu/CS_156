# %% [markdown]
# # <b>CS156 (Introduction to AI), Spring 2022</b>
# # <u><b>Homework 1 submission</b></u>

# %% [markdown]
# ### Roster Name: Benjamin Wu
# ### Student ID: 013607880
# ### Email address: benjamin.wu01@sjsu.edu

# %% [markdown]
# ##  <u>Solution</u>

# %% [markdown]
# ## Import libraries, setup random seed

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
np.random.seed(42)

# %% [markdown]
# ##  <u>References and sources </u>

# %% [markdown]
# List all your references and sources here.
# This includes all sites/discussion boards/blogs/posts/etc. where you grabbed some code examples.

# %% [markdown]
# ## Code the solution

# %%
df1 = pd.read_csv("./dataset/root_games.csv", low_memory=False)
df2 = pd.read_csv("./dataset/tail_games1.csv", low_memory=False)
df3 = pd.read_csv("./dataset/tail_games2.csv", low_memory=False)
df4 = pd.read_csv("./dataset/tail_games3.csv", low_memory=False)
df5 = pd.read_csv("./dataset/tail_games4.csv", low_memory=False)

# %%
df = pd.concat([df1, df2, df3, df4, df5])

print(df.columns.tolist())

# print(df["teamId_100.win"])
labels = df["teamId_100.win"]
# print(df.loc("teamId_100.win"))
X_train, X_test, Y_train, Y_test = train_test_split(df,labels, test_size=0.2, random_state=0)
# Out:
# ['gameId', 'platformId', 'gameCreation', 'gameDuration', 'queueId', 'mapId', 'seasonId', 'gameVersion', 'gameMode', 'gameType', 'banned1.championId', 'banned2.championId', 'banned3.championId', 'banned4.championId', 'banned5.championId', 'banned6.championId', 'banned7.championId', 'banned8.championId', 'banned9.championId', 'banned10.championId', 'participant1.teamId', 'participant1.championId', 'participant1.spell1Id', 'participant1.spell2Id', 'participant1.stats.participantId', 'participant1.stats.win', 'participant1.stats.item0', 'participant1.stats.item1', 'participant1.stats.item2', 'participant1.stats.item3', 'participant1.stats.item4', 'participant1.stats.item5', 'participant1.stats.item6', 'participant1.stats.kills', 'participant1.stats.deaths', 'participant1.stats.assists', 'participant1.stats.largestKillingSpree', 'participant1.stats.largestMultiKill', 'participant1.stats.killingSprees', 'participant1.stats.longestTimeSpentLiving', 'participant1.stats.doubleKills', 'participant1.stats.tripleKills', 'participant1.stats.quadraKills', 'participant1.stats.pentaKills', 'participant1.stats.unrealKills', 'participant1.stats.totalDamageDealt', 'participant1.stats.magicDamageDealt', 'participant1.stats.physicalDamageDealt', 'participant1.stats.trueDamageDealt', 'participant1.stats.largestCriticalStrike', 'participant1.stats.totalDamageDealtToChampions', 'participant1.stats.magicDamageDealtToChampions', 'participant1.stats.physicalDamageDealtToChampions', 'participant1.stats.trueDamageDealtToChampions', 'participant1.stats.totalHeal', 'participant1.stats.totalUnitsHealed', 'participant1.stats.damageSelfMitigated', 'participant1.stats.damageDealtToObjectives', 'participant1.stats.damageDealtToTurrets', 'participant1.stats.visionScore', 'participant1.stats.timeCCingOthers', 'participant1.stats.totalDamageTaken', 'participant1.stats.magicalDamageTaken', 'participant1.stats.physicalDamageTaken', 'participant1.stats.trueDamageTaken', 'participant1.stats.goldEarned', 'participant1.stats.goldSpent', 'participant1.stats.turretKills', 'participant1.stats.inhibitorKills', 'participant1.stats.totalMinionsKilled', 'participant1.stats.neutralMinionsKilled', 'participant1.stats.neutralMinionsKilledTeamJungle', 'participant1.stats.neutralMinionsKilledEnemyJungle', 'participant1.stats.totalTimeCrowdControlDealt', 'participant1.stats.champLevel', 'participant1.stats.visionWardsBoughtInGame', 'participant1.stats.sightWardsBoughtInGame', 'participant1.stats.wardsPlaced', 'participant1.stats.wardsKilled', 'participant1.stats.firstBloodKill', 'participant1.stats.firstBloodAssist', 'participant1.stats.firstTowerKill', 'participant1.stats.firstTowerAssist', 'participant1.stats.firstInhibitorKill', 'participant1.stats.firstInhibitorAssist', 'participant1.stats.combatPlayerScore', 'participant1.stats.objectivePlayerScore', 'participant1.stats.totalPlayerScore', 'participant1.stats.totalScoreRank', 'participant1.stats.playerScore0', 'participant1.stats.playerScore1', 'participant1.stats.playerScore2', 'participant1.stats.playerScore3', 'participant1.stats.playerScore4', 'participant1.stats.playerScore5', 'participant1.stats.playerScore6', 'participant1.stats.playerScore7', 'participant1.stats.playerScore8', 'participant1.stats.playerScore9', 'participant1.stats.perk0', 'participant1.stats.perk0Var1', 'participant1.stats.perk0Var2', 'participant1.stats.perk0Var3', 'participant1.stats.perk1', 'participant1.stats.perk1Var1', 'participant1.stats.perk1Var2', 'participant1.stats.perk1Var3', 'participant1.stats.perk2', 'participant1.stats.perk2Var1', 'participant1.stats.perk2Var2', 'participant1.stats.perk2Var3', 'participant1.stats.perk3', 'participant1.stats.perk3Var1', 'participant1.stats.perk3Var2', 'participant1.stats.perk3Var3', 'participant1.stats.perk4', 'participant1.stats.perk4Var1', 'participant1.stats.perk4Var2', 'participant1.stats.perk4Var3', 'participant1.stats.perk5', 'participant1.stats.perk5Var1', 'participant1.stats.perk5Var2', 'participant ...

# %%
model = linear_model.LinearRegression().fit(X_train[[""]], Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\benja\Documents\School\CS_156\TermProject\WuBenjaminAssignment.ipynb Cell 12' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/benja/Documents/School/CS_156/TermProject/WuBenjaminAssignment.ipynb#ch0000011?line=0'>1</a> model = linear_model.LinearRegression().fit(X_train, Y_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/linear_model/_base.py?line=657'>658</a> n_jobs_ = self.n_jobs
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/linear_model/_base.py?line=659'>660</a> accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/linear_model/_base.py?line=661'>662</a> X, y = self._validate_data(
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/linear_model/_base.py?line=662'>663</a>     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/linear_model/_base.py?line=663'>664</a> )
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/linear_model/_base.py?line=665'>666</a> if sample_weight is not None:
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/linear_model/_base.py?line=666'>667</a>     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/base.py?line=578'>579</a>         y = check_array(y, **check_y_params)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/base.py?line=579'>580</a>     else:
# --> <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/base.py?line=580'>581</a>         X, y = check_X_y(X, y, **check_params)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/base.py?line=581'>582</a>     out = X, y
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/base.py?line=583'>584</a> if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=960'>961</a> if y is None:
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=961'>962</a>     raise ValueError("y cannot be None")
# --> <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=963'>964</a> X = check_array(
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=964'>965</a>     X,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=965'>966</a>     accept_sparse=accept_sparse,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=966'>967</a>     accept_large_sparse=accept_large_sparse,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=967'>968</a>     dtype=dtype,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=968'>969</a>     order=order,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=969'>970</a>     copy=copy,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=970'>971</a>     force_all_finite=force_all_finite,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=971'>972</a>     ensure_2d=ensure_2d,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=972'>973</a>     allow_nd=allow_nd,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=973'>974</a>     ensure_min_samples=ensure_min_samples,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=974'>975</a>     ensure_min_features=ensure_min_features,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=975'>976</a>     estimator=estimator,
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=976'>977</a> )
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=978'>979</a> y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=980'>981</a> check_consistent_length(X, y)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=743'>744</a>         array = array.astype(dtype, casting="unsafe", copy=False)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=744'>745</a>     else:
# --> <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=745'>746</a>         array = np.asarray(array, order=order, dtype=dtype)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=746'>747</a> except ComplexWarning as complex_warning:
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=747'>748</a>     raise ValueError(
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=748'>749</a>         "Complex data not supported\n{}\n".format(array)
#     <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/utils/validation.py?line=749'>750</a>     ) from complex_warning
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=2070'>2071</a> def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> <a href='file:///c%3A/Users/benja/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=2071'>2072</a>     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'NA1'
